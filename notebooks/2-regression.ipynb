# %%
# Imports
# Visualize
import matplotlib.pyplot as plt
# Data
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from neuroHarmonize import harmonizationLearn
# Fit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
from statsmodels.nonparametric.smoothers_lowess import lowess
from sklearn.linear_model import RidgeCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.base import clone, BaseEstimator, RegressorMixin
from sklearn.utils.validation import check_is_fitted
from sklearn.kernel_ridge import KernelRidge

# %% [markdown]
# Now we will try to predict the brain age based on the EDA we did before. Let's start by visualizing the cortical thicknesses relations with the age

# %%
# We will use this as our demogprahic dataset
masterfile_path = "../data/IXI/subjects.csv"
masterfile = pd.read_csv(masterfile_path)
masterfile = masterfile[masterfile["age"] != -1.0]
masterfile.head(5)
# Out:
#   subject_id    age     sex       scanner                  site diagnosis  \
# 0     IXI002  35.80  Female  Philips-1.5T        Guy’s-Hospital   Healthy
# 1     IXI012  38.78    Male  Philips-3.0T  Hammersmith-Hospital   Healthy
# 2     IXI013  46.71    Male  Philips-3.0T  Hammersmith-Hospital   Healthy
# 3     IXI014  34.24  Female  Philips-3.0T  Hammersmith-Hospital   Healthy
# 4     IXI015  24.28    Male  Philips-3.0T  Hammersmith-Hospital   Healthy
#
#   dataset_name subject_key  session  run  \
# 0          IXI  IXI002_IXI        1    1
# 1          IXI  IXI012_IXI        1    1
# 2          IXI  IXI013_IXI        1    1
# 3          IXI  IXI014_IXI        1    1
# 4          IXI  IXI015_IXI        1    1
#
#                                       registered_mni
# 0  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 1  sub-IXI012/ses-1/run-1/anat/sub-IXI012_acq-Phi...
# 2  sub-IXI013/ses-1/run-1/anat/sub-IXI013_acq-Phi...
# 3  sub-IXI014/ses-1/run-1/anat/sub-IXI014_acq-Phi...
# 4  sub-IXI015/ses-1/run-1/anat/sub-IXI015_acq-Phi...

# %%
thickness_df = pd.read_csv("../data/IXI/thickness.csv")
thickness_df
# Out:
#       subject_id hemi                   region  mean_thickness_weighted  \
# 0         IXI002   lh                  unknown                 0.000369
# 1         IXI002   lh  caudalanteriorcingulate                 2.767575
# 2         IXI002   lh      caudalmiddlefrontal                 2.828643
# 3         IXI002   lh                   cuneus                 2.019888
# 4         IXI002   lh               entorhinal                 2.712761
# ...          ...  ...                      ...                      ...
# 37063     IXI662   rh         superiorparietal                 2.120859
# 37064     IXI662   rh         superiortemporal                 2.965944
# 37065     IXI662   rh            supramarginal                 2.508402
# 37066     IXI662   rh       transversetemporal                 2.354042
# 37067     IXI662   rh                   insula                 3.162511
#
#        mean_thickness_simple  n_vertices   total_area
# 0                   0.000338        8853  5502.432653
# 1                   2.609781        1437  1083.926104
# 2                   2.690581        3830  2769.405243
# 3                   2.020947        2739  2037.500121
# 4                   2.636525         708   687.427367
# ...                      ...         ...          ...
# 37063               2.023058        6653  5314.046982
# 37064               2.796967        8804  7119.010455
# 37065               2.370133        5606  4399.206890
# 37066               2.350365         628   446.668808
# 37067               3.093791        3507  2240.559767
#
# [37068 rows x 7 columns]

# %% [markdown]
# Let's see how the thickness values changes based on the age.

# %%
merged = thickness_df.merge(masterfile, on='subject_id', how='inner')
merged['age'] = pd.to_numeric(merged['age'], errors='coerce')
merged['mean_thickness_weighted'] = pd.to_numeric(merged['mean_thickness_weighted'], errors='coerce')
merged['mean_thickness_simple'] = pd.to_numeric(merged['mean_thickness_simple'], errors='coerce')
merged = merged.dropna(subset=['age', 'sex', 'mean_thickness_weighted', 'mean_thickness_simple'])

merged.head(3)
# Out:
#   subject_id hemi                   region  mean_thickness_weighted  \
# 0     IXI002   lh                  unknown                 0.000369
# 1     IXI002   lh  caudalanteriorcingulate                 2.767575
# 2     IXI002   lh      caudalmiddlefrontal                 2.828643
#
#    mean_thickness_simple  n_vertices   total_area   age     sex       scanner  \
# 0               0.000338        8853  5502.432653  35.8  Female  Philips-1.5T
# 1               2.609781        1437  1083.926104  35.8  Female  Philips-1.5T
# 2               2.690581        3830  2769.405243  35.8  Female  Philips-1.5T
#
#              site diagnosis dataset_name subject_key  session  run  \
# 0  Guy’s-Hospital   Healthy          IXI  IXI002_IXI        1    1
# 1  Guy’s-Hospital   Healthy          IXI  IXI002_IXI        1    1
# 2  Guy’s-Hospital   Healthy          IXI  IXI002_IXI        1    1
#
#                                       registered_mni
# 0  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 1  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 2  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...

# %%
import numpy as np
import matplotlib.pyplot as plt

def scatter_region_vs_age(
    df,
    region_name,
    hemi=None,
    thickness='mean_thickness_weighted',
    min_points=2,  # minimum points to fit a line
):
    # Filter
    sub = df[df['region'] == region_name].copy()
    if hemi is not None:
        sub = sub[sub['hemi'] == hemi]
    
    if sub.empty:
        raise ValueError(f"No data for region={region_name}" + (f", hemi={hemi}" if hemi else ""))
    
    fig, ax = plt.subplots(figsize=(7,5))
    
    # Scatter by sex with per-sex linear fit
    for sex, g in sub.groupby('sex'):
        x = g['age'].values
        y = g[thickness].values
        ax.scatter(x, y, alpha=0.6, s=25, label=f"sex={sex} data")
        
        if len(x) >= min_points:
            # Consider only valid data
            valid_mask = (~np.isnan(x)) & (~np.isnan(y))
            x_clean = x[valid_mask]
            y_clean = y[valid_mask]

            # we check if we have enough value
            if len(x_clean) >= min_points:

                # we do a very easy least square and plot the line
                m, b = np.polyfit(x_clean, y_clean, 1)
                xs = np.linspace(x_clean.min(), x_clean.max(), 100)
                yhat = m * xs + b

                # Quick approximation of fit quality (R2)
                ss_res = np.sum((y_clean - (m * x_clean + b))**2)
                ss_tot = np.sum((y_clean - np.mean(y_clean))**2)
                r2 = 1 - ss_res / ss_tot if ss_tot > 0 else np.nan
                ax.plot(xs, yhat, linestyle='--', linewidth=2, label=f"sex={sex} fit: slope={m:.3f}, R²={r2:.2f}")

        # We calculate the correlation of the specific region
        corr = g['age'].corr(g[thickness])
        ax.text(
            0.02,
            0.95 - 0.05 * list(sub['sex'].unique()).index(sex),
            f"{sex} r={corr:.2f}",
            transform=ax.transAxes,
            va='top',
            fontsize=9
        )

    ax.set_xlabel("Age")
    ax.set_ylabel(thickness)
    title = f"{thickness} vs Age in region='{region_name}'"
    if hemi:
        title += f" (hemi={hemi})"
    ax.set_title(title)
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.2)
    plt.tight_layout()
    plt.show()

scatter_region_vs_age(merged, "caudalanteriorcingulate", "rh")

# %%
scatter_region_vs_age(merged, "transversetemporal", "lh")

# %% [markdown]
# As we can see, considering distinct values of the regions is not very informative
# To prove this, the linear fit shows very low R2 values. However, some of them are non-negligeable.
# We also get a first look on how the single subjects charactertics affects the estimation.

# %% [markdown]
# Let's use a simple regression to try to predict the brian age. First, let's divide our dataset in useful groups.

# %%
# Let's extract the per thickness matrix
def make_thickness_matrix(df,
                          sample_id_cols=['subject_id', 'session', 'run'],
                          metadata_cols=['age', 'sex', 'scanner', 'site', 'diagnosis', 'dataset_name'],
                          value_col='mean_thickness_weighted',
                          hemi_col='hemi',
                          region_col='region',
                          aggfunc='mean'):
    df = df.copy()
    df['sample_id'] = df[sample_id_cols].astype(str).agg('_'.join, axis=1)

    # pivoting
    index_cols = ['sample_id'] + list(sample_id_cols) + list(metadata_cols)
    pivot = df.pivot_table(
        index=index_cols,
        columns=[hemi_col, region_col],
        values=value_col,
        aggfunc=aggfunc  # if duplicates exist (e.g., multiple entries), aggregate
    )

    pivot.columns = [f"{hemi}_{region}" for hemi, region in sorted(pivot.columns)]
    wide_df = pivot.reset_index()

    return wide_df

# %% [markdown]
# Before creating the thickness matrix, let's make sure that the thickness is well defined for all the regions

# %%
merged['sample_id'] = merged[['subject_id', 'session', 'run']].astype(str).agg('_'.join, axis=1)
coverage = (merged
            .drop_duplicates(subset=['sample_id', 'hemi', 'region'])
            .groupby(['hemi', 'region'])['sample_id']
            .nunique()
            .sort_values(ascending=True))
print(coverage)
# Out:
# hemi  region
# rh    temporalpole                 2
# lh    caudalanteriorcingulate    560
# rh    cuneus                     560
#       entorhinal                 560
#       fusiform                   560
#                                 ...
# lh    superiorparietal           560
#       superiortemporal           560
#       supramarginal              560
#       unknown                    560
# rh    unknown                    560
# Name: sample_id, Length: 65, dtype: int64

# %% [markdown]
# As you can see, we have only 2 samples with temporalpole rh region. Let's investigate why

# %%
thickness_matrix_df = make_thickness_matrix(
    df=merged,
    value_col='mean_thickness_weighted'
)
thickness_matrix_df.isna().sum().sort_values(ascending=False)
# Out:
# rh_temporalpole           558
# sample_id                   0
# rh_inferiorparietal         0
# rh_medialorbitofrontal      0
# rh_lingual                  0
#                          ...
# lh_paracentral              0
# lh_middletemporal           0
# lh_medialorbitofrontal      0
# lh_lingual                  0
# rh_unknown                  0
# Length: 75, dtype: int64

# %%
# We get the samples with the temporal pole defined
sel = merged[
    (merged['hemi'].str.strip() == 'rh') &
    (merged['region'].str.strip().str.lower() == 'temporalpole')
]

print("Sample IDs with rh temporalpole:")
print(sel['sample_id'].unique())
print("Count:", sel['sample_id'].nunique())
# Out:
# Sample IDs with rh temporalpole:
# ['IXI199_1_1' 'IXI447_1_1']
# Count: 2

# %%
for sid in sel['sample_id'].unique():
    subset = merged[(merged['sample_id'] == sid) &
                    (merged['hemi'].str.strip() == 'rh') &
                    (merged['region'].str.strip().str.lower() == 'temporalpole')]
    print(f"--- {sid} ---")
    print(subset[['mean_thickness_weighted', 'mean_thickness_simple', 'n_vertices', 'total_area']])
# Out:
# --- IXI199_1_1 ---
#        mean_thickness_weighted  mean_thickness_simple  n_vertices  total_area
# 11009                 1.216443                1.22908          35   17.150712
# --- IXI447_1_1 ---
#        mean_thickness_weighted  mean_thickness_simple  n_vertices  total_area
# 24840                 0.911163               0.921729           4    2.341295

# %% [markdown]
# We see the area is very little. We can remove this from our analysis, together with "unknown"

# %%
merged_filtered = merged[~((merged["region"] == 'temporalpole') & (merged["hemi"] == "rh") | (merged["region"] == "unknown"))]
merged_filtered
# Out:
#       subject_id hemi                   region  mean_thickness_weighted  \
# 1         IXI002   lh  caudalanteriorcingulate                 2.767575
# 2         IXI002   lh      caudalmiddlefrontal                 2.828643
# 3         IXI002   lh                   cuneus                 2.019888
# 4         IXI002   lh               entorhinal                 2.712761
# 5         IXI002   lh                 fusiform                 2.841887
# ...          ...  ...                      ...                      ...
# 35847     IXI662   rh         superiorparietal                 2.120859
# 35848     IXI662   rh         superiortemporal                 2.965944
# 35849     IXI662   rh            supramarginal                 2.508402
# 35850     IXI662   rh       transversetemporal                 2.354042
# 35851     IXI662   rh                   insula                 3.162511
#
#        mean_thickness_simple  n_vertices   total_area    age     sex  \
# 1                   2.609781        1437  1083.926104  35.80  Female
# 2                   2.690581        3830  2769.405243  35.80  Female
# 3                   2.020947        2739  2037.500121  35.80  Female
# 4                   2.636525         708   687.427367  35.80  Female
# 5                   2.664019        3645  2744.754747  35.80  Female
# ...                      ...         ...          ...    ...     ...
# 35847               2.023058        6653  5314.046982  41.74    Male
# 35848               2.796967        8804  7119.010455  41.74    Male
# 35849               2.370133        5606  4399.206890  41.74    Male
# 35850               2.350365         628   446.668808  41.74    Male
# 35851               3.093791        3507  2240.559767  41.74    Male
#
#             scanner            site diagnosis dataset_name subject_key  \
# 1      Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI002_IXI
# 2      Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI002_IXI
# 3      Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI002_IXI
# 4      Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI002_IXI
# 5      Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI002_IXI
# ...             ...             ...       ...          ...         ...
# 35847  Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI662_IXI
# 35848  Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI662_IXI
# 35849  Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI662_IXI
# 35850  Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI662_IXI
# 35851  Philips-1.5T  Guy’s-Hospital   Healthy          IXI  IXI662_IXI
#
#        session  run                                     registered_mni  \
# 1            1    1  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 2            1    1  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 3            1    1  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 4            1    1  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 5            1    1  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# ...        ...  ...                                                ...
# 35847        1    1  sub-IXI662/ses-1/run-1/anat/sub-IXI662_acq-Phi...
# 35848        1    1  sub-IXI662/ses-1/run-1/anat/sub-IXI662_acq-Phi...
# 35849        1    1  sub-IXI662/ses-1/run-1/anat/sub-IXI662_acq-Phi...
# 35850        1    1  sub-IXI662/ses-1/run-1/anat/sub-IXI662_acq-Phi...
# 35851        1    1  sub-IXI662/ses-1/run-1/anat/sub-IXI662_acq-Phi...
#
#         sample_id
# 1      IXI002_1_1
# 2      IXI002_1_1
# 3      IXI002_1_1
# 4      IXI002_1_1
# 5      IXI002_1_1
# ...           ...
# 35847  IXI662_1_1
# 35848  IXI662_1_1
# 35849  IXI662_1_1
# 35850  IXI662_1_1
# 35851  IXI662_1_1
#
# [34720 rows x 18 columns]

# %%
proper_thickness_matrix_df = make_thickness_matrix(
    df=merged_filtered,
    value_col='mean_thickness_weighted'
)
proper_thickness_matrix_df
# Out:
#       sample_id subject_id  session  run    age     sex       scanner  \
# 0    IXI002_1_1     IXI002        1    1  35.80  Female  Philips-1.5T
# 1    IXI012_1_1     IXI012        1    1  38.78    Male  Philips-3.0T
# 2    IXI013_1_1     IXI013        1    1  46.71    Male  Philips-3.0T
# 3    IXI014_1_1     IXI014        1    1  34.24  Female  Philips-3.0T
# 4    IXI015_1_1     IXI015        1    1  24.28    Male  Philips-3.0T
# ..          ...        ...      ...  ...    ...     ...           ...
# 555  IXI648_1_1     IXI648        1    1  47.72    Male  Philips-1.5T
# 556  IXI651_1_1     IXI651        1    1  50.40    Male  Philips-1.5T
# 557  IXI652_1_1     IXI652        1    1  42.99    Male  Philips-1.5T
# 558  IXI653_1_1     IXI653        1    1  46.22    Male  Philips-1.5T
# 559  IXI662_1_1     IXI662        1    1  41.74    Male  Philips-1.5T
#
#                      site diagnosis dataset_name  ...  rh_posteriorcingulate  \
# 0          Guy’s-Hospital   Healthy          IXI  ...               2.526792
# 1    Hammersmith-Hospital   Healthy          IXI  ...               2.110860
# 2    Hammersmith-Hospital   Healthy          IXI  ...               2.187725
# 3    Hammersmith-Hospital   Healthy          IXI  ...               2.389425
# 4    Hammersmith-Hospital   Healthy          IXI  ...               2.433594
# ..                    ...       ...          ...  ...                    ...
# 555        Guy’s-Hospital   Healthy          IXI  ...               2.368956
# 556        Guy’s-Hospital   Healthy          IXI  ...               2.557057
# 557        Guy’s-Hospital   Healthy          IXI  ...               2.369852
# 558        Guy’s-Hospital   Healthy          IXI  ...               2.390742
# 559        Guy’s-Hospital   Healthy          IXI  ...               2.413669
#
#      rh_precentral  rh_precuneus  rh_rostralanteriorcingulate  \
# 0         2.669832      2.474847                     2.899147
# 1         2.525746      2.131758                     2.652905
# 2         2.163080      1.949073                     2.655105
# 3         2.560258      2.035774                     2.726204
# 4         2.717191      2.267934                     2.859262
# ..             ...           ...                          ...
# 555       2.488031      2.258418                     2.473333
# 556       2.424307      2.153154                     2.723620
# 557       2.642250      2.324239                     2.607858
# 558       2.531981      2.459577                     2.844242
# 559       2.452114      2.292555                     2.590287
#
#      rh_rostralmiddlefrontal  rh_superiorfrontal  rh_superiorparietal  \
# 0                   2.635482            3.117611             2.317504
# 1                   2.352631            2.635217             2.109884
# 2                   2.347103            2.558824             2.037381
# 3                   2.491766            2.670686             2.029425
# 4                   2.545136            2.780078             2.166804
# ..                       ...                 ...                  ...
# 555                 2.196754            2.557564             2.053742
# 556                 2.550233            2.665893             2.130979
# 557                 2.499192            2.840999             2.260241
# 558                 2.584192            2.829947             2.300675
# 559                 2.421116            2.621681             2.120859
#
#      rh_superiortemporal  rh_supramarginal  rh_transversetemporal
# 0               3.213092          2.725745               2.460538
# 1               2.871431          2.485718               2.019534
# 2               2.887120          2.578263               1.791700
# 3               2.860698          2.461032               1.714474
# 4               2.979659          2.727619               2.119733
# ..                   ...               ...                    ...
# 555             2.590609          2.288504               2.097680
# 556             2.914703          2.471970               1.841894
# 557             3.093230          2.665132               2.402448
# 558             3.066660          2.734182               2.315479
# 559             2.965944          2.508402               2.354042
#
# [560 rows x 72 columns]

# %% [markdown]
# Let's define the datasets

# %%
test_set = proper_thickness_matrix_df[proper_thickness_matrix_df["scanner"] == "GE-1.5T"]
train_set = proper_thickness_matrix_df[proper_thickness_matrix_df["scanner"] != "GE-1.5T"]

test_set["subject_id"].nunique(), train_set["subject_id"].nunique()
# Out:
# (66, 494)

# %% [markdown]
# Why no split like 80%/20%? In clinical setting, we are often interested in how a prediction algorithm generalizes on unknown data. We want to have a predictor that is easily trasferrable to other sites and scanner. Thus, we try to account for this property in test by excluding one of the scanners from the train set
# On the training set, we will do the usual division

# %%
train_set.columns
# Out:
# Index(['sample_id', 'subject_id', 'session', 'run', 'age', 'sex', 'scanner',
#        'site', 'diagnosis', 'dataset_name', 'lh_caudalanteriorcingulate',
#        'lh_caudalmiddlefrontal', 'lh_cuneus', 'lh_entorhinal', 'lh_fusiform',
#        'lh_inferiorparietal', 'lh_inferiortemporal', 'lh_insula',
#        'lh_isthmuscingulate', 'lh_lateraloccipital', 'lh_lateralorbitofrontal',
#        'lh_lingual', 'lh_medialorbitofrontal', 'lh_middletemporal',
#        'lh_paracentral', 'lh_parahippocampal', 'lh_parsopercularis',
#        'lh_parsorbitalis', 'lh_parstriangularis', 'lh_pericalcarine',
#        'lh_postcentral', 'lh_posteriorcingulate', 'lh_precentral',
#        'lh_precuneus', 'lh_rostralanteriorcingulate',
#        'lh_rostralmiddlefrontal', 'lh_superiorfrontal', 'lh_superiorparietal',
#        'lh_superiortemporal', 'lh_supramarginal', 'lh_transversetemporal',
#        'rh_caudalanteriorcingulate', 'rh_caudalmiddlefrontal', 'rh_cuneus',
#        'rh_entorhinal', 'rh_fusiform', 'rh_inferiorparietal',
#        'rh_inferiortemporal', 'rh_insula', 'rh_isthmuscingulate',
#        'rh_lateraloccipital', 'rh_lateralorbitofrontal', 'rh_lingual',
#        'rh_medialorbitofrontal', 'rh_middletemporal', 'rh_paracentral',
#        'rh_parahippocampal', 'rh_parsopercularis', 'rh_parsorbitalis',
#        'rh_parstriangularis', 'rh_pericalcarine', 'rh_postcentral',
#        'rh_posteriorcingulate', 'rh_precentral', 'rh_precuneus',
#        'rh_rostralanteriorcingulate', 'rh_rostralmiddlefrontal',
#        'rh_superiorfrontal', 'rh_superiorparietal', 'rh_superiortemporal',
#        'rh_supramarginal', 'rh_transversetemporal'],
#       dtype='object')

# %%
labels_features = [c for c in train_set.columns if "lh" in c or "rh" in c]
labels_features[:5]
# Out:
# ['lh_caudalanteriorcingulate',
#  'lh_caudalmiddlefrontal',
#  'lh_cuneus',
#  'lh_entorhinal',
#  'lh_fusiform']

# %%
# Define features
X = train_set[labels_features].values  # start with one raw thickness measure
y = train_set['age'].values

# Validation of about ~20%
indices = np.arange(len(train_set))
tr_idx, te_idx = train_test_split(indices, test_size=0.2, random_state=0)

X_tr = X[tr_idx]
X_te = X[te_idx]
y_tr = y[tr_idx]
y_te = y[te_idx]

# %%
# Let's fit a linear regression without many problems.
model = LinearRegression()
model.fit(X_tr, y_tr)
y_pred = model.predict(X_te)

# %%
# And evaluate.
mae = mean_absolute_error(y_te, y_pred) # Why mae? :)
r2 = r2_score(y_te, y_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_pred - y_te
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_te, y_pred, alpha=0.6)
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 9.952, R²: 0.497
# Mean brain age gap (pred − true): 0.175

# %% [markdown]
# It seems we got a fairly good model: R2 is good, MAE is a bit high. Can we guess why?
# Let's change a bit the setting: we use this result to build an auxiliary model to predict age gap

# %%
bias_model = LinearRegression().fit(y_te.reshape(-1,1), gap) # <- note, we are using the real age, which in theory we don't have access to!
predicted_gap = bias_model.predict(y_te.reshape(-1,1))

plt.figure()
plt.scatter(y_te, gap, alpha=0.6, label='gap')
plt.plot(y_te, predicted_gap, 'r--', label=f'fit slope={bias_model.coef_[0]:.3f}')
plt.xlabel("True age")
plt.ylabel("Brain age gap (pred − true)")
plt.title("Bias: gap vs true age")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# What is this telling us? :)

# %% [markdown]
# Let's take into considerations the subject with the highest error

# %%
errors = np.abs(y_pred - y_te)
idx_sorted = np.argsort(-errors)  # descending
topk = 5
for i in idx_sorted[:topk]:
    print(f"Sample {i}: true age={y_te[i]:.1f}, pred={y_pred[i]:.1f}, error={errors[i]:.2f}")
# Out:
# Sample 72: true age=59.9, pred=86.2, error=26.35
# Sample 43: true age=29.0, pred=53.8, error=24.79
# Sample 39: true age=73.6, pred=50.6, error=22.93
# Sample 47: true age=75.6, pred=53.4, error=22.22
# Sample 82: true age=79.4, pred=57.3, error=22.07

# %%
train_set.iloc[te_idx[idx_sorted[:topk]]]
# Out:
#       sample_id subject_id  session  run    age     sex       scanner  \
# 359  IXI417_1_1     IXI417        1    1  59.88    Male  Philips-1.5T
# 114  IXI135_1_1     IXI135        1    1  29.00    Male  Philips-1.5T
# 284  IXI327_1_1     IXI327        1    1  73.56    Male  Philips-3.0T
# 133  IXI158_1_1     IXI158        1    1  75.63  Female  Philips-1.5T
# 388  IXI448_1_1     IXI448        1    1  79.41    Male  Philips-3.0T
#
#                      site diagnosis dataset_name  ...  rh_posteriorcingulate  \
# 359        Guy’s-Hospital   Healthy          IXI  ...               2.379771
# 114        Guy’s-Hospital   Healthy          IXI  ...               2.706621
# 284  Hammersmith-Hospital   Healthy          IXI  ...               2.341492
# 133        Guy’s-Hospital   Healthy          IXI  ...               2.297943
# 388  Hammersmith-Hospital   Healthy          IXI  ...               2.618786
#
#      rh_precentral  rh_precuneus  rh_rostralanteriorcingulate  \
# 359       2.150974      2.134901                     2.504101
# 114       2.559589      2.392805                     2.867407
# 284       2.596301      2.233497                     2.676799
# 133       2.225371      2.342985                     2.701188
# 388       2.296445      2.160813                     2.740014
#
#      rh_rostralmiddlefrontal  rh_superiorfrontal  rh_superiorparietal  \
# 359                 2.196837            2.442319             2.169522
# 114                 2.487334            2.726078             2.289662
# 284                 2.371612            2.574451             2.195186
# 133                 2.425102            2.618560             2.128800
# 388                 2.572247            2.639678             2.139952
#
#      rh_superiortemporal  rh_supramarginal  rh_transversetemporal
# 359             2.804760          2.282834               2.549284
# 114             2.815380          2.597338               2.681163
# 284             3.026949          2.687759               2.249851
# 133             3.063336          2.544517               2.578491
# 388             2.752182          2.401460               1.971724
#
# [5 rows x 72 columns]

# %% [markdown]
# In practice, our model is naively converging to the mean prediction, as we are doing an high error on the tail of the distribution. We can confirm this behaviour on the test set.

# %%
X_test_set = test_set[labels_features].values
y_test_set = test_set["age"].values

# %%
whole_model = LinearRegression()
whole_model.fit(X, y) # Both train, val
y_test_pred = whole_model.predict(X_test_set)

# %%
# And evaluate.
mae = mean_absolute_error(y_test_set, y_test_pred)
r2 = r2_score(y_test_set, y_test_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_test_pred - y_test_set
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_test_set, y_test_pred, alpha=0.6)
plt.plot([y_test_set.min(), y_test_set.max()],
         [y_test_set.min(), y_test_set.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 13.375, R²: 0.001
# Mean brain age gap (pred − true): 9.916

# %% [markdown]
# All the very young sample we have are completely wrong :(
# Can we improve?
# The first step is to correct our prediction based on the fitted bias

# %%
# Prediction on the validation set are corrected based on the predicted gap
y_pred_corrected = y_pred - predicted_gap

# Evaluate after correction
mae_corr = mean_absolute_error(y_te, y_pred_corrected)
r2_corr = r2_score(y_te, y_pred_corrected)
print(f"After bias correction MAE: {mae_corr:.3f}, R²: {r2_corr:.3f}")

# Plot corrected vs true
plt.figure()
plt.scatter(y_te, y_pred_corrected, alpha=0.6, label="corrected")
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Corrected predicted age")
plt.title("Bias-corrected prediction")
plt.legend()
plt.show()
# Out:
# After bias correction MAE: 6.825, R²: 0.738

# %% [markdown]
# This is extremely good... but you see an error?
# Let's do this in the proper way

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=0) # <- We use only the train set!
oof_pred = np.zeros_like(y_tr)
for train_idx, val_idx in kf.split(X_tr):
    model_cv = LinearRegression()
    model_cv.fit(X_tr[train_idx], y_tr[train_idx])
    # We set the prediction based on the fold preformances 
    oof_pred[val_idx] = model_cv.predict(X_tr[val_idx])

gap_oof = oof_pred - y_tr
bias_model_oof = LinearRegression().fit(oof_pred.reshape(-1,1), gap_oof)

# %%
# Predict the expected bias from the predicted age
predicted_gap_corrected = bias_model_oof.predict(y_pred.reshape(-1,1))
# Corrected age
y_pred_corrected_no_leak = y_pred - predicted_gap_corrected

# %%
# Evaluate after correction
mae_corr = mean_absolute_error(y_te, y_pred_corrected_no_leak)
r2_corr = r2_score(y_te, y_pred_corrected_no_leak)
print(f"After bias correction MAE: {mae_corr:.3f}, R²: {r2_corr:.3f}")

# Plot corrected vs true
plt.figure()
plt.scatter(y_te, y_pred_corrected_no_leak, alpha=0.6, label="corrected")
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Corrected predicted age with no validation leak")
plt.title("Bias-corrected prediction")
plt.legend()
plt.show()
# Out:
# After bias correction MAE: 10.337, R²: 0.481

# %% [markdown]
# Interestingly, when we fit the model with the correction we got a worse outcome! Why?

# %% [markdown]
# Let's investigate by visualizing the new bias prediction

# %%
pred_gap = bias_model_oof.predict(oof_pred.reshape(-1,1))
print("Bias model R²:", r2_score(gap_oof, pred_gap))
# Out:
# Bias model R²: 0.043380397831981554

# %% [markdown]
# Basically our model R2 is very low... it's most likely we are fitting noise. So this age prediction correction is not really working in our favour here.
# Maybe there is no age correction we can apply?

# %%
# We plot a smooth curve to understand the relationship between
# - The predicted ages `oof_pred`
# - The error with the true age
smoothed = lowess(gap_oof, oof_pred, frac=0.3)  # adjust frac for more/less smoothing

plt.figure()
plt.scatter(oof_pred, gap_oof, alpha=0.4, label="OOF gap")
plt.plot(smoothed[:,0], smoothed[:,1], 'r-', label="Lowess trend")
plt.axhline(0, linestyle='--', color='k')
plt.xlabel("Predicted age (OOF)")
plt.ylabel("Gap (pred − true)")
plt.title("Bias structure: is gap predictable from prediction?")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# We see tha the curve is flat, with a little wiggle. Most likely it's noise, so it means we can't exploit any bias for our data.
# That's what happening: we are adding noise with the correction, and the prediction fails!

# %% [markdown]
# At this point, let's try to improve the model by a different approach.
# The cortical thickness may not capture the true age relationship due to covariates (sex, site, scanner). Let's include them

# %%
covariates_labels = ["sex", "site", "scanner"]

# %%
X_all_df = train_set[labels_features + covariates_labels].fillna("missing")
X_all_df.head(3)
# Out:
#    lh_caudalanteriorcingulate  lh_caudalmiddlefrontal  lh_cuneus  \
# 0                    2.767575                2.828643   2.019888
# 1                    2.400216                2.533996   1.716370
# 2                    2.520548                2.499412   1.458557
#
#    lh_entorhinal  lh_fusiform  lh_inferiorparietal  lh_inferiortemporal  \
# 0       2.712761     2.841887             2.487441             3.102358
# 1       3.097469     2.224258             2.323388             2.750064
# 2       2.951624     2.219040             2.405152             2.770652
#
#    lh_insula  lh_isthmuscingulate  lh_lateraloccipital  ...  \
# 0   3.180834             2.489012             2.139495  ...
# 1   3.022653             2.081978             1.909471  ...
# 2   3.022749             2.035213             1.790117  ...
#
#    rh_rostralanteriorcingulate  rh_rostralmiddlefrontal  rh_superiorfrontal  \
# 0                     2.899147                 2.635482            3.117611
# 1                     2.652905                 2.352631            2.635217
# 2                     2.655105                 2.347103            2.558824
#
#    rh_superiorparietal  rh_superiortemporal  rh_supramarginal  \
# 0             2.317504             3.213092          2.725745
# 1             2.109884             2.871431          2.485718
# 2             2.037381             2.887120          2.578263
#
#    rh_transversetemporal     sex                  site       scanner
# 0               2.460538  Female        Guy’s-Hospital  Philips-1.5T
# 1               2.019534    Male  Hammersmith-Hospital  Philips-3.0T
# 2               1.791700    Male  Hammersmith-Hospital  Philips-3.0T
#
# [3 rows x 65 columns]

# %% [markdown]
# We can easily manipulate pandas like feature with processors in sklearn

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), labels_features),
        ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates_labels),
    ],
    remainder="drop",
)

# Define the model
model = Pipeline([
    ("preproc", preprocessor),
    ("reg", LinearRegression())
])

# %%
X_tr_all_df = X_all_df.iloc[tr_idx]
X_te_all_df = X_all_df.iloc[te_idx]

# %%
model.fit(X_tr_all_df, y_tr)
y_pred = model.predict(X_te_all_df)

mae = mean_absolute_error(y_te, y_pred)
r2 = r2_score(y_te, y_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_pred - y_te
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_te, y_pred, alpha=0.6)
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 9.797, R²: 0.519
# Mean brain age gap (pred − true): 0.313

# %% [markdown]
# We slightly improve the model! Very good news. Except... we still have the same issue!
# Could be that... maybe site and scanners are not that useful? Let's investigate.

# %%
model["reg"].coef_, len(model["reg"].coef_)
# Out:
# (array([-1.88142496e+00,  3.92820151e-02,  5.63330551e-01, -8.85800774e-01,
#          1.29481125e+00, -1.25452349e+00,  3.13903016e+00,  2.04128347e+00,
#         -6.32626924e-01,  5.02620301e-01,  6.94294712e-01, -1.27966829e+00,
#         -1.59753520e+00,  9.85380427e-01,  2.48499065e+00,  7.28685930e-01,
#         -1.36972432e+00,  2.42617922e-01, -4.08305523e+00,  1.77747168e+00,
#          1.68680226e+00, -2.09903012e-02, -2.56898022e+00,  1.13558137e+00,
#          6.92261781e-01,  1.36011011e+00, -4.11521582e+00,  1.30167071e-01,
#         -1.23201612e+00,  6.52969270e-01, -3.64679925e-01, -2.55108585e-01,
#          1.93763305e-02, -1.54870962e+00,  1.05689042e+00, -1.32268069e+00,
#         -1.64604075e+00,  1.59777430e+00, -3.41644932e-01, -2.50367093e+00,
#          1.57390239e+00,  1.96186665e-02,  3.09717331e+00, -1.47650869e+00,
#          1.17854060e-02, -2.01749880e+00,  8.47233872e-01, -2.77059191e+00,
#         -7.45864453e-01, -5.16895169e-01,  1.36378681e+00,  1.01453800e-01,
#          1.92401283e+00, -2.10009958e+00,  1.40057216e+00,  1.05684539e+00,
#         -1.64032606e+00, -1.84484031e-01,  1.51685225e+00, -2.95513427e+00,
#          8.69230749e-01, -2.71598092e-01, -4.07987262e+00,  8.79191320e+12,
#         -8.79191320e+12]),
#  65)

# %% [markdown]
# Can we guess why the site and scanner coefficients are very high?

# %%
covariates_labels_no_site = ["sex", "scanner"]

preprocessor_no_site = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), labels_features),
        ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates_labels_no_site),
    ],
    remainder="drop", # We drop the site
)

# Define the model
model_no_site = Pipeline([
    ("preproc", preprocessor_no_site),
    ("reg", LinearRegression())
])

# %%
model_no_site.fit(X_tr_all_df, y_tr)
y_pred = model_no_site.predict(X_te_all_df)

mae = mean_absolute_error(y_te, y_pred)
r2 = r2_score(y_te, y_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_pred - y_te
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_te, y_pred, alpha=0.6)
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 9.797, R²: 0.519
# Mean brain age gap (pred − true): 0.313

# %%
model_no_site["reg"].coef_, len(model_no_site["reg"].coef_)
# Out:
# (array([-1.88102376,  0.04025395,  0.56321951, -0.88642764,  1.29567527,
#         -1.25374183,  3.13817584,  2.04249011, -0.6316084 ,  0.50262001,
#          0.69366183, -1.27700455, -1.59775459,  0.98461678,  2.48545774,
#          0.72904896, -1.37068889,  0.24252778, -4.08280961,  1.7761826 ,
#          1.68578835, -0.02157119, -2.56890615,  1.13399671,  0.69125699,
#          1.36056705, -4.11536075,  0.12987718, -1.23136799,  0.65454711,
#         -0.36628497, -0.25418979,  0.01970542, -1.54786866,  1.05692157,
#         -1.32407176, -1.64656719,  1.59710489, -0.34134426, -2.50478881,
#          1.57430056,  0.02084103,  3.09559469, -1.47637572,  0.01082913,
#         -2.01765965,  0.84731851, -2.77153909, -0.74567412, -0.5165285 ,
#          1.36409512,  0.10293261,  1.92467708, -2.09940415,  1.39948123,
#          1.05689018, -1.64062222, -0.18573761,  1.51760548, -2.95384549,
#          0.86862316, -0.27144232, -4.07817954,  3.44957342]),
#  64)

# %% [markdown]
# Turns out site and scanner were extremely correlated! Dropping the site makes the weights much better. So the improvement is quite important. What happens when we don't consider the site/scanner altoghether?

# %%
covariates_labels_only_sex = ["sex"]

preprocessor_only_sex = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), labels_features),
        ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates_labels_only_sex),
    ],
    remainder="drop", # We drop the site
)

# Define the model
model_only_sex = Pipeline([
    ("preproc", preprocessor_only_sex),
    ("reg", LinearRegression())
])

# %%
model_only_sex.fit(X_tr_all_df, y_tr)
y_pred = model_only_sex.predict(X_te_all_df)

mae = mean_absolute_error(y_te, y_pred)
r2 = r2_score(y_te, y_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_pred - y_te
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_te, y_pred, alpha=0.6)
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 9.711, R²: 0.523
# Mean brain age gap (pred − true): 0.399

# %% [markdown]
# Scanner is confounding our prediction! We got a better model ignoring the scanner effect.
# Could we understand it before? let's see the relationship of age vs scanner/site

# %%
covs = train_set[["site", "scanner"]].fillna("missing")
X_site_scanner = pd.get_dummies(covs, drop_first=True)

age = train_set["age"].values
lr = LinearRegression()
lr.fit(X_site_scanner, age)
pred_age_from_site = lr.predict(X_site_scanner)

print("R² of age predicted from site+scanner alone:", r2_score(age, pred_age_from_site))
# Out:
# R² of age predicted from site+scanner alone: 0.0040369570783856945

# %% [markdown]
# So, relying on site and scanner alone makes it impossible to predict the age.
# And when we inclue only the site and scanner instead of sex?

# %%
covariates_labels_only_scanner = ["scanner"]

preprocessor_only_scanner = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), labels_features),
        ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates_labels_only_scanner),
    ],
    remainder="drop", # We drop the site
)

# Define the model
model_only_scanner = Pipeline([
    ("preproc", preprocessor_only_scanner),
    ("reg", LinearRegression())
])

# %%
model_only_scanner.fit(X_tr_all_df, y_tr)
y_pred = model_only_scanner.predict(X_te_all_df)

mae = mean_absolute_error(y_te, y_pred)
r2 = r2_score(y_te, y_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_pred - y_te
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_te, y_pred, alpha=0.6)
plt.plot([y_te.min(), y_te.max()],
         [y_te.min(), y_te.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 10.014, R²: 0.496
# Mean brain age gap (pred − true): 0.103

# %% [markdown]
# In our final model we won't include scanner.
# This is also intuitive: the scanner effect is partially encoded in the cortical thickness feature. When we include the scanner, the following may happen
# - we have less representative scanners (remember eda... this is true)
# - scanners may be linked to the age in a non trivial way (in a specific scanner we only scanned people in a certain age range)

# %%
# let's write a little function that allows us to test quickly various model
def evaluate_models_with_cv(df: pd.DataFrame,
                            labels_features,
                            include_scanner=False,
                            include_sex=False,
                            model_reg=None,
                            n_splits=5,
                            random_state=0,):
    if model_reg is None:
        model_reg = LinearRegression()

    covariates = []
    if include_scanner:
        covariates.append("scanner")
    if include_sex:
        covariates.append("sex")

    transformers = [("num", StandardScaler(), labels_features)]
    if covariates: # only if we have covariates we append
        transformers.append(
            ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates)
        )

    preprocessor = ColumnTransformer(transformers=transformers, remainder="drop")

    model = Pipeline([
        ("preproc", preprocessor),
        ("reg", model_reg)
    ])

    X: pd.DataFrame = df[labels_features + covariates]
    y = df["age"].values

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    preds = np.zeros(len(y))

    for train_idx, val_idx in kf.split(np.arange(len(X))):
        X_tr = X.iloc[train_idx]
        X_val = X.iloc[val_idx]
        y_tr = y[train_idx]

        m = clone(model)
        m.fit(X_tr, y_tr)
        preds[val_idx] = m.predict(X_val)

    return {
        "r2": r2_score(y, preds),
        "mae": mean_absolute_error(y, preds),
        "preds": preds,
        "fitted_whole_model": clone(model).fit(X, y)
    }

# Evaluate
res_base = evaluate_models_with_cv(train_set, labels_features, include_scanner=False)
res_scanner = evaluate_models_with_cv(train_set, labels_features, include_scanner=True)
res_sex = evaluate_models_with_cv(train_set, labels_features, include_sex=True)
res_both = evaluate_models_with_cv(train_set, labels_features, include_scanner=True, include_sex=True)

print("Thickness only R²:", res_base["r2"], "MAE:", res_base["mae"])
print("Thickness + scanner R²:", res_scanner["r2"], "MAE:", res_scanner["mae"])
print("Thickness + sex R²:", res_sex["r2"], "MAE:", res_sex["mae"])
print("Thickness + scanner + sex R²:", res_both["r2"], "MAE:", res_both["mae"])
# Out:
# Thickness only R²: 0.4491875502599263 MAE: 9.921819442366983
# Thickness + scanner R²: 0.4488638770709876 MAE: 9.93409176566096
# Thickness + sex R²: 0.4618442282501902 MAE: 9.761747304804048
# Thickness + scanner + sex R²: 0.4624454868247121 MAE: 9.779456827372549

# %% [markdown]
# We discovered that the model with the scanner included is on par with the sex one, which confirms our hypotesis!
# This also removes a problem we would have in test. The scanner is unknown, and thus it would be not possible to use our model on test set:

# %%
whole_model = res_both["fitted_whole_model"]
y_test_pred = whole_model.predict(test_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 2
#       1 whole_model = res_both["fitted_whole_model"]
# ----> 2 y_test_pred = whole_model.predict(test_set)
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:600, in Pipeline.predict(self, X, **params)
#     598 if not _routing_enabled():
#     599     for _, name, transform in self._iter(with_final=False):
# --> 600         Xt = transform.transform(Xt)
#     601     return self.steps[-1][1].predict(Xt, **params)
#     603 # metadata routing enabled
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:1076, in ColumnTransformer.transform(self, X, **params)
#    1073 else:
#    1074     routed_params = self._get_empty_routing()
# -> 1076 Xs = self._call_func_on_transformers(
#    1077     X,
#    1078     None,
#    1079     _transform_one,
#    1080     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1081     routed_params=routed_params,
#    1082 )
#    1083 self._validate_output(Xs)
#    1085 if not Xs:
#    1086     # All transformers are None
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:885, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     873             extra_args = {}
#     874         jobs.append(
#     875             delayed(func)(
#     876                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     882             )
#     883         )
# --> 885     return Parallel(n_jobs=self.n_jobs)(jobs)
#     887 except ValueError as e:
#     888     if "Expected 2D array, got 1D array instead" in str(e):
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:1290, in _transform_one(transformer, X, y, weight, params)
#    1268 def _transform_one(transformer, X, y, weight, params=None):
#    1269     """Call transform and apply weight to output.
#    1270
#    1271     Parameters
#    (...)
#    1288         This should be of the form ``process_routing()["step_name"]``.
#    1289     """
# -> 1290     res = transformer.transform(X, **params.transform)
#    1291     # if we have a weight for this transformer, multiply output
#    1292     if weight is None:
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:1024, in OneHotEncoder.transform(self, X)
#    1019 # validation of X happens in _check_X called by _transform
#    1020 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1021     "ignore",
#    1022     "infrequent_if_exist",
#    1023 }
# -> 1024 X_int, X_mask = self._transform(
#    1025     X,
#    1026     handle_unknown=self.handle_unknown,
#    1027     force_all_finite="allow-nan",
#    1028     warn_on_unknown=warn_on_unknown,
#    1029 )
#    1031 n_samples, n_features = X_int.shape
#    1033 if self._drop_idx_after_grouping is not None:
#
# File /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:214, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     209 if handle_unknown == "error":
#     210     msg = (
#     211         "Found unknown categories {0} in column {1}"
#     212         " during transform".format(diff, i)
#     213     )
# --> 214     raise ValueError(msg)
#     215 else:
#     216     if warn_on_unknown:
#
# ValueError: Found unknown categories ['GE-1.5T'] in column 0 during transform

# %% [markdown]
# So we can only use the sex one, unless we rely on mixed models that allow to learn the scanner effects as random effects / account for scanner residuals.

# %%
whole_model = res_sex["fitted_whole_model"]
y_test_pred = whole_model.predict(test_set)

# %%
# And evaluate.
mae = mean_absolute_error(y_test_set, y_test_pred)
r2 = r2_score(y_test_set, y_test_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_test_pred - y_test_set
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_test_set, y_test_pred, alpha=0.6)
plt.plot([y_test_set.min(), y_test_set.max()],
         [y_test_set.min(), y_test_set.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 14.273, R²: -0.132
# Mean brain age gap (pred − true): 10.866

# %% [markdown]
# However, as we can see, on the test set we still have an huge problem! Can we try better approaches?
# Let's try to understand if this is possibly related to a scanner shift. One of the most well known technique to take this kind of scanner shifts effect in consideration is harmonization.
# ComBat is one of the most known technique for this

# %%
# Directly extract thickness
X_train_thick = train_set[labels_features].values
X_test_thick = test_set[labels_features].values

# We need to format properly for combat
def prepare_covars(df):
    cov = pd.DataFrame({
        "SITE": df["scanner"].astype(str),
        "SEX": df["sex"].map({"Male": 1, "Female": 0}) if df["sex"].dtype == object else df["sex"].astype(float),
        "AGE": df["age"].astype(float)
    })
    return cov

covars_train = prepare_covars(train_set)
covars_test = prepare_covars(test_set)

# We slightly clip the ages to account for the fact that we have a discrepancy in age range covered from test set, but it's negligeable.
age_min = covars_train["AGE"].min()
age_max = covars_train["AGE"].max()

# small epsilon to avoid exact boundary issues
eps = 1e-6
covars_test_adj = covars_test.copy()
covars_test_adj["AGE"] = covars_test_adj["AGE"].clip(lower=age_min + eps, upper=age_max - eps)

# Via smooth_terms, we specify the variables which can model non-linear effects with the input variables (cortical thickness)
smooth_terms = ["AGE"] 

model, X_train_combat = harmonizationLearn(
    X_train_thick,
    covars_train,
    eb=True,
    # smooth_terms=smooth_terms,
    return_s_data=False
)

# %%
train_set_combat, test_set_combat = train_set.copy(), test_set.copy()
train_set_combat[labels_features] = X_train_combat
# test_set_combat[labels_features] = X_test_combat

# %% [markdown]
# And now we use this normalized features.

# %%
# Evaluate
def evaluate_models_with_cv_and_stratified(df: pd.DataFrame,
                                            labels_features,
                                            include_scanner=False,
                                            include_sex=False,
                                            model_reg=None,
                                            n_splits=5,
                                            random_state=0,):
    # Add age_bin
    internal_df = df.copy()
    internal_df["age_bin"] = pd.cut(df["age"], bins=10, labels=False, include_lowest=True)
    internal_df["stratify_key"] = internal_df["age_bin"].astype(str) + "_" + internal_df["sex"].astype(str)
    
    if model_reg is None:
        model_reg = LinearRegression()

    covariates = []
    if include_scanner:
        covariates.append("scanner")
    if include_sex:
        covariates.append("sex")

    transformers = [("num", StandardScaler(), labels_features)]
    if covariates: # only if we have covariates we append
        transformers.append(
            ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates)
        )

    preprocessor = ColumnTransformer(transformers=transformers, remainder="drop")

    model = Pipeline([
        ("preproc", preprocessor),
        ("reg", model_reg)
    ])

    X: pd.DataFrame = internal_df[labels_features + covariates]
    y = internal_df["age"].values

    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    preds = np.zeros(len(y))

    for train_idx, val_idx in kf.split(np.arange(len(X)), internal_df["stratify_key"].values):
        X_tr = X.iloc[train_idx]
        X_val = X.iloc[val_idx]
        y_tr = y[train_idx]

        m = clone(model)
        m.fit(X_tr, y_tr)
        preds[val_idx] = m.predict(X_val)

    return {
        "r2": r2_score(y, preds),
        "mae": mean_absolute_error(y, preds),
        "preds": preds,
        "fitted_whole_model": clone(model).fit(X, y)
    }

res_base = evaluate_models_with_cv_and_stratified(train_set_combat, labels_features, include_scanner=False, model_reg=RidgeCV(alphas=np.logspace(-3, 3, 15), cv=3))
res_scanner = evaluate_models_with_cv_and_stratified(train_set_combat, labels_features, include_scanner=True, model_reg=RidgeCV(alphas=np.logspace(-3, 3, 15), cv=3))
res_sex = evaluate_models_with_cv_and_stratified(train_set_combat, labels_features, include_sex=True, model_reg=RidgeCV(alphas=np.logspace(-3, 3, 15), cv=3))
res_both = evaluate_models_with_cv_and_stratified(train_set_combat, labels_features, include_scanner=True, include_sex=True, model_reg=RidgeCV(alphas=np.logspace(-3, 3, 15), cv=3))

print("Thickness only R²:", res_base["r2"], "MAE:", res_base["mae"])
print("Thickness + scanner R²:", res_scanner["r2"], "MAE:", res_scanner["mae"])
print("Thickness + sex R²:", res_sex["r2"], "MAE:", res_sex["mae"])
print("Thickness + scanner + sex R²:", res_both["r2"], "MAE:", res_both["mae"])
# Out:
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Thickness only R²: 0.45889578266795794 MAE: 9.895158889472794
# Thickness + scanner R²: 0.4592264701573857 MAE: 9.887848792478994
# Thickness + sex R²: 0.4669588757596762 MAE: 9.802206599919712
# Thickness + scanner + sex R²: 0.4702293531613164 MAE: 9.812196979384533

# %%
whole_model = res_sex["fitted_whole_model"]
y_test_pred = whole_model.predict(test_set)

# %%
# And evaluate.
mae = mean_absolute_error(y_test_set, y_test_pred)
r2 = r2_score(y_test_set, y_test_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_test_pred - y_test_set
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_test_set, y_test_pred, alpha=0.6)
plt.plot([y_test_set.min(), y_test_set.max()],
         [y_test_set.min(), y_test_set.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 14.229, R²: -0.096
# Mean brain age gap (pred − true): 10.691

# %% [markdown]
# Even using combat and learn an invariant version doesn't help with the prediction. Probably we don't have sufficient data for combat.
# Before wrapping up the lesson with non-linear models, I would like to introduce an additional way to deal with this error in prediction
# Recent research shown that a Correlation Constrained Ridge Regression may help with keeping the bias in check (https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.615754/full)
#
# Let's try to implement it

# %%
def age_delta_correlation(y_true, y_pred):
    # delta = predicted - true; ADC = corr(true, delta)
    delta = y_pred - y_true
    if np.std(delta) == 0 or np.std(y_true) == 0:
        return 0.0
    return np.corrcoef(y_true, delta)[0, 1]

class CorrelationConstrainedKernelRidge(BaseEstimator, RegressorMixin):
    """
    Kernel Ridge with an explicit bound on the age-delta correlation (ADC).
    Implements the analytic bounded-correlation solution from Treder et al. 2021.
    If |ADC| <= rho, keeps the unconstrained solution. Otherwise rescales the
    predictions by a factor theta so that |ADC| == rho with the same sign.
    """
    def __init__(self, alpha=1.0, kernel='rbf', gamma=None, rho=0.0):
        self.alpha = alpha  # regularization
        self.kernel = kernel
        self.gamma = gamma
        self.rho = rho  # allowed absolute age-delta correlation (ρ in paper)

    def fit(self, X, y):
        # fit a kernel ridge (ridge regression based on kernels, for instant the rbf)
        self.krr_ = KernelRidge(alpha=self.alpha, kernel=self.kernel, gamma=self.gamma)
        self.krr_.fit(X, y)

        # We get a "age" prediction
        y_hat = self.krr_.predict(X) 

        # We ge the correlation between the original age and the predicted age
        adc = age_delta_correlation(y, y_hat)

        if abs(adc) <= self.rho:
            # No constraint violated: keep original dual coefficients
            # the dual coefficients are the coefficients of the ridge regression that weights the kernel terms 
            self.dual_coef_ = self.krr_.dual_coef_.copy()
            self._theta = 1.0

        else:
            # We need to find a dual coefficient scaler such that
            # corr(y, delta_cc) = sign(adc)*rho
            # where: delta_cc = y_hat_cc - y = contrained_model(X) - y

            # We'll search the two analytic roots from Treder et al. and pick the one
            # that achieves the desired sign and magnitude.
            y_vec = y.reshape(-1)
            y_hat_vec = y_hat.reshape(-1)
            # Define quantities
            norm_y2 = np.dot(y_vec, y_vec)  # ||y||^2
            norm_yhat2 = np.dot(y_hat_vec, y_hat_vec)  # ||ŷ||^2
            yT_yhat = np.dot(y_vec, y_hat_vec)  # y^T ŷ
            target_adc = np.sign(adc) * self.rho

            # The idea is to solve the optimization problem of corr(y, delta_cc) = sign(adc)*rho
            # And you can express it as corr(y, e_cc) = -corr(y, delta_cc)
            # where e = y - ŷ = -delta

            rho_e = abs(target_adc)  # magnitude for their formula
            c = (yT_yhat ** 2) - (rho_e ** 2) * norm_y2 * norm_yhat2
            # If c is zero or numerically problematic, fall back to no scaling
            
            if np.isclose(c, 0):
                self.dual_coef_ = self.krr_.dual_coef_.copy()
                self._theta = 1.0

            else:
                # We use the analitical solution from the paper
                term1 = norm_y2 * yT_yhat * (1 - rho_e ** 2) / c

                inside_sqrt = rho_e ** 2 * (1 - rho_e ** 2) * (norm_y2 * norm_yhat2 - yT_yhat ** 2)
                if inside_sqrt < 0:
                    # numerical issues; clamp to zero
                    inside_sqrt = 0.0

                # This can be both positive or negative
                term2 = (norm_y2 / abs(c)) * np.sqrt(inside_sqrt)
                # so we have to solutions
                theta_candidates = [term1 + term2, term1 - term2]

                # We evaluate which candidate gives desired ADC (within tolerance)
                best_theta = None
                best_diff = np.inf
                for theta in theta_candidates:
                    y_hat_cc = theta * y_hat_vec
                    adc_cc = age_delta_correlation(y_vec, y_hat_cc)
                    # We want |adc_cc| close to |target_adc| and sign matching
                    if np.sign(adc_cc) != np.sign(target_adc):
                        continue
                    diff = abs(abs(adc_cc) - abs(target_adc))
                    if diff < best_diff:
                        best_diff = diff
                        best_theta = theta
                        
                if best_theta is None:
                    # fallback: choose theta that minimizes squared difference to target
                    # even if sign mismatches
                    best_theta = min(theta_candidates, key=lambda th: abs(abs(age_delta_correlation(y_vec, th * y_hat_vec)) - abs(target_adc)))
                self._theta = best_theta
                # Scale dual coefficients
                self.dual_coef_ = self.krr_.dual_coef_ * self._theta

        # Store training data needed for prediction (KernelRidge keeps theirs internally)
        self.X_fit_ = X
        self.y_fit_ = y
        return self

    def predict(self, X):
        check_is_fitted(self, "dual_coef_")
        # Use underlying kernel evaluation, but with possibly scaled dual coefficients
        # Reproduce prediction logic of KernelRidge: K(X, X_fit_) @ dual_coef_
        # Leverage the fitted kernel function from underlying object:
        # We can use the private _get_kernel in KernelRidge via its parameters.
        from sklearn.metrics.pairwise import pairwise_kernels
        K = pairwise_kernels(
            X,
            self.X_fit_,
            metric=self.kernel,
            filter_params=True,
            **({"gamma": self.gamma} if self.gamma is not None else {})
        )
        return K.dot(self.dual_coef_)

# %%
def evaluate_models_with_cv_and_stratified_and_tune(df: pd.DataFrame,
                                            labels_features,
                                            include_scanner=False,
                                            include_sex=False,
                                            model_reg=None,
                                            n_splits=5,
                                            random_state=0,
                                            param_grid = None):
    # Add age_bin
    internal_df = df.copy()
    internal_df["age_bin"] = pd.cut(df["age"], bins=10, labels=False, include_lowest=True)
    internal_df["stratify_key"] = internal_df["age_bin"].astype(str) + "_" + internal_df["sex"].astype(str)
    
    if model_reg is None:
        model_reg = LinearRegression()

    covariates = []
    if include_scanner:
        covariates.append("scanner")
    if include_sex:
        covariates.append("sex")

    transformers = [("num", StandardScaler(), labels_features)]
    if covariates: # only if we have covariates we append
        transformers.append(
            ("cat", OneHotEncoder(drop="first", sparse_output=False), covariates)
        )

    preprocessor = ColumnTransformer(transformers=transformers, remainder="drop")

    pipeline = Pipeline([
        ("preproc", preprocessor),
        ("reg", model_reg)
    ])

    X: pd.DataFrame = internal_df[labels_features + covariates]
    y = internal_df["age"].values

    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    preds = np.zeros(len(y))

    eff_model = pipeline
    splits = list(outer_cv.split(np.arange(len(X)), internal_df["stratify_key"].values))

    if param_grid is not None:
        # Cv is used for estimating the best parameter for the model
        search = GridSearchCV(
            estimator=clone(pipeline),
            param_grid=param_grid,
            cv=splits,
            scoring="neg_mean_absolute_error",
            refit=True,
            n_jobs=1,
        )
        search.fit(X, y)
        eff_model = search.best_estimator_

    # We fit the (maybe best) model on the splits
    for (train_idx, val_idx) in splits:
        X_tr = X.iloc[train_idx]
        X_val = X.iloc[val_idx]
        y_tr = y[train_idx]
        y_val = y[val_idx]
        
        m = clone(eff_model)
        m.fit(X_tr, y_tr) # Refit
        preds[val_idx] = m.predict(X_val)

    return {
        "r2": r2_score(y, preds),
        "mae": mean_absolute_error(y, preds),
        "preds": preds,
        "fitted_whole_model": clone(eff_model).fit(X, y)
    }

# %%
# We will try it
PARAM_GRID = {
    "reg__alpha": [0.01, 0.1, 1.0],
    "reg__gamma": [0.01, 0.1, 1.0],
    "reg__rho": [0.0, 0.01, 0.05, 0.1],
}

res_base = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_scanner=False, model_reg=CorrelationConstrainedKernelRidge(alpha=1.0, kernel="rbf"), param_grid=PARAM_GRID)
res_scanner = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_scanner=True, model_reg=CorrelationConstrainedKernelRidge(alpha=1.0, kernel="rbf"), param_grid=PARAM_GRID)
res_sex = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_sex=True, model_reg=CorrelationConstrainedKernelRidge(alpha=1.0, kernel="rbf"), param_grid=PARAM_GRID)
res_both = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_scanner=True, include_sex=True, model_reg=CorrelationConstrainedKernelRidge(alpha=1.0, kernel="rbf"), param_grid=PARAM_GRID)

print("Thickness only R²:", res_base["r2"], "MAE:", res_base["mae"])
print("Thickness + scanner R²:", res_scanner["r2"], "MAE:", res_scanner["mae"])
print("Thickness + sex R²:", res_sex["r2"], "MAE:", res_sex["mae"])
print("Thickness + scanner + sex R²:", res_both["r2"], "MAE:", res_both["mae"])
# Out:
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Thickness only R²: 0.2953745866574553 MAE: 10.945649826564885
# Thickness + scanner R²: 0.2950984775824169 MAE: 10.922368137102254
# Thickness + sex R²: 0.3125360799041602 MAE: 10.807633698096136
# Thickness + scanner + sex R²: 0.3130412585210389 MAE: 10.789246228778229

# %%
whole_model = res_sex["fitted_whole_model"]
y_test_pred = whole_model.predict(test_set)

# %%
# And evaluate.
mae = mean_absolute_error(y_test_set, y_test_pred)
r2 = r2_score(y_test_set, y_test_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_test_pred - y_test_set
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_test_set, y_test_pred, alpha=0.6)
plt.plot([y_test_set.min(), y_test_set.max()],
         [y_test_set.min(), y_test_set.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 12.842, R²: -0.056
# Mean brain age gap (pred − true): 0.075

# %% [markdown]
# At this point we can evaluate other type of possible regressors

# %%
PARAM_GRID = {
    "reg__max_depth": [6,8,12],
    "reg__n_estimators": [100,200,300]
}

res_base = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_scanner=False, model_reg=RandomForestRegressor(n_estimators=200, max_depth=8, random_state=0), param_grid=PARAM_GRID)
res_scanner = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_scanner=True, model_reg=RandomForestRegressor(n_estimators=200, max_depth=8, random_state=0), param_grid=PARAM_GRID)
res_sex = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_sex=True, model_reg=RandomForestRegressor(n_estimators=200, max_depth=8, random_state=0), param_grid=PARAM_GRID)
res_both = evaluate_models_with_cv_and_stratified_and_tune(train_set, labels_features, include_scanner=True, include_sex=True, model_reg=RandomForestRegressor(n_estimators=200, max_depth=8, random_state=0), param_grid=PARAM_GRID)

print("Thickness only R²:", res_base["r2"], "MAE:", res_base["mae"])
print("Thickness + scanner R²:", res_scanner["r2"], "MAE:", res_scanner["mae"])
print("Thickness + sex R²:", res_sex["r2"], "MAE:", res_sex["mae"])
print("Thickness + scanner + sex R²:", res_both["r2"], "MAE:", res_both["mae"])
# Out:
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/afrotscher/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Thickness only R²: 0.4484813260064129 MAE: 9.825163824060008
# Thickness + scanner R²: 0.4475672937532633 MAE: 9.851974772739187
# Thickness + sex R²: 0.45114978831743013 MAE: 9.803342314244322
# Thickness + scanner + sex R²: 0.446978068011638 MAE: 9.842580649598283

# %%
whole_model = res_sex["fitted_whole_model"]
y_test_pred = whole_model.predict(test_set)

# %%
# And evaluate.
mae = mean_absolute_error(y_test_set, y_test_pred)
r2 = r2_score(y_test_set, y_test_pred)
print(f"Naive linear regression MAE: {mae:.3f}, R²: {r2:.3f}")

# Brain age gap
gap = y_test_pred - y_test_set
print(f"Mean brain age gap (pred − true): {np.mean(gap):.3f}")

# Plot
plt.figure()
plt.scatter(y_test_set, y_test_pred, alpha=0.6)
plt.plot([y_test_set.min(), y_test_set.max()],
         [y_test_set.min(), y_test_set.max()], 'k--', label='identity')
plt.xlabel("True age")
plt.ylabel("Predicted age")
plt.title("Naive prediction: Predicted vs True Age")
plt.legend()
plt.show()

plt.figure()
plt.hist(gap, bins=30)
plt.xlabel("Brain age gap (pred − true)")
plt.title("Distribution of naive brain age gap")
plt.show()
# Out:
# Naive linear regression MAE: 13.622, R²: 0.043
# Mean brain age gap (pred − true): 8.859

# %% [markdown]
# Many things may still be tried: What do you think about?

# %% [markdown]
# - Try to fit a Ridge Regression on the cortical thickness without using the combat harmonized features. Do you see any improvement?
# - Residualization: usually it is useful to consider the prediction of ages with residuals of the features we are interested in with respect of their regresson in terms of covariates (scanner/site). Try to implement this approach.
# - Mixed Effect Modelling is something I have introduced here but not properly tackled. Try to use the `statsmodels` `MixedLM` model and predict the age using scanner as a random effect ($\text{age} \sim \text{thickness features} + (1|\text{scanner})$)
