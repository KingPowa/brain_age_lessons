# %% [markdown]
# This is just a demostration on how I got the regional averaged values

# %%
import os
import numpy as np
import pandas as pd
from nibabel.freesurfer.io import read_morph_data, read_annot, read_geometry

# %%
masterfile_path = "/work/fsammarco/datasets/IXI/subjects.csv" # This is different from the one you have availble in the lessons...
masterfile = pd.read_csv(masterfile_path)
masterfile.head(5)
# Out:
#   subject_id    age     sex       scanner                  site diagnosis  \
# 0     IXI002  35.80  Female  Philips-1.5T        Guy’s-Hospital   Healthy
# 1     IXI012  38.78    Male  Philips-3.0T  Hammersmith-Hospital   Healthy
# 2     IXI013  46.71    Male  Philips-3.0T  Hammersmith-Hospital   Healthy
# 3     IXI014  34.24  Female  Philips-3.0T  Hammersmith-Hospital   Healthy
# 4     IXI015  24.28    Male  Philips-3.0T  Hammersmith-Hospital   Healthy
#
#   dataset_name subject_key  session  run  \
# 0          IXI  IXI002_IXI        1    1
# 1          IXI  IXI012_IXI        1    1
# 2          IXI  IXI013_IXI        1    1
# 3          IXI  IXI014_IXI        1    1
# 4          IXI  IXI015_IXI        1    1
#
#                                       registered_mni
# 0  sub-IXI002/ses-1/run-1/anat/sub-IXI002_acq-Phi...
# 1  sub-IXI012/ses-1/run-1/anat/sub-IXI012_acq-Phi...
# 2  sub-IXI013/ses-1/run-1/anat/sub-IXI013_acq-Phi...
# 3  sub-IXI014/ses-1/run-1/anat/sub-IXI014_acq-Phi...
# 4  sub-IXI015/ses-1/run-1/anat/sub-IXI015_acq-Phi...

# %%
def get_paths(hemi, row):
    base = "/var/datasets/IXI/freesurfer8/preproc_subjects"
    row[f"{hemi}_thickness"] = os.path.join(base, f'sub-{row["subject_id"]}', "surf", f"{hemi}.thickness")
    row[f"{hemi}_pial"] = os.path.join(base, f'sub-{row["subject_id"]}', "surf", f"{hemi}.pial")
    row[f"{hemi}_annot"] = os.path.join(base, f'sub-{row["subject_id"]}', "label", f"{hemi}.aparc.DKTatlas.annot")
    return row

masterfile = masterfile.apply(lambda x: get_paths("lh", x), axis=1)
masterfile = masterfile.apply(lambda x: get_paths("rh", x), axis=1)

# %%
"""
Compute area-weighted and simple mean thickness per region for one subject and both hemispheres.
annotation: one of "aparc", "aparc.DKTatlas", "aparc.a2009s" (matching the .annot filename)
Returns a DataFrame with columns: subject, hemi, region, mean_thickness_weighted, mean_thickness_simple
"""
results = []
for _, row in masterfile.iterrows():
    for hemi in ("lh", "rh"):
        # subject id
        subject_id = row["subject_id"]

        # paths
        thickness_path = row[f"{hemi}_thickness"]
        print(thickness_path)
        annot_path = row[f"{hemi}_annot"]
        print(annot_path)
        surface_path = row[f"{hemi}_pial"]
        print(surface_path)
        print("Processing...")
        
        # sanity check
        if not (os.path.isfile(thickness_path) and os.path.isfile(annot_path) and os.path.isfile(surface_path)):
            raise FileNotFoundError(f"Missing file for subject={subject_id}, hemi={hemi}")
        
        # load data
        thickness = read_morph_data(thickness_path)  # per-vertex
        labels, ctab, names = read_annot(annot_path)
        coords, faces = read_geometry(surface_path)
        
        # compute face areas
        v0 = coords[faces[:, 0], :]
        v1 = coords[faces[:, 1], :]
        v2 = coords[faces[:, 2], :]
        face_areas = 0.5 * np.linalg.norm(np.cross(v1 - v0, v2 - v0), axis=1)
        
        # distribute to vertices (1/3 each adjacent face)
        vertex_area = np.zeros(coords.shape[0])
        for vi in range(3):
            np.add.at(vertex_area, faces[:, vi], face_areas / 3.0)
        
        # region-wise means
        unique_labels = np.unique(labels)
        for lab in unique_labels:
            mask = labels == lab
            if not np.any(mask):
                continue
            areas = vertex_area[mask]

            total_area = float(np.sum(areas))
            n_vertices = int(mask.sum())

            t_vals = thickness[mask]
            mean_thick_weighted = np.sum(t_vals * areas) / total_area
            mean_thick_simple = np.mean(t_vals)

            if int(lab) == -1:
                region_name = "unknown"
            else:
                region_name = names[int(lab)].decode("utf-8")
                
            results.append({
                "subject_id": subject_id,
                "hemi": hemi,
                "region": region_name,
                "mean_thickness_weighted": mean_thick_weighted,
                "mean_thickness_simple": mean_thick_simple,
                "n_vertices": n_vertices,
                "total_area": total_area
            })
thickness_df = pd.DataFrame(results)
# Out:
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI002/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI002/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI002/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI002/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI002/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI002/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI012/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI012/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI012/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI012/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI012/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI012/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI013/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI013/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI013/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI013/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI013/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI013/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI014/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI014/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI014/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI014/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI014/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI014/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI015/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI015/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI015/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI015/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI015/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI015/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI016/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI016/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI016/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI016/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI016/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI016/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI017/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI017/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI017/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI017/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI017/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI017/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI019/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI019/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI019/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI019/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI019/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI019/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI020/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI020/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI020/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI020/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI020/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI020/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI021/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI021/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI021/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI021/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI021/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI021/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI022/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI022/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI022/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI022/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI022/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI022/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI023/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI023/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI023/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI023/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI023/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI023/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI024/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI024/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI024/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI024/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI024/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI024/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI025/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI025/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI025/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI025/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI025/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI025/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI026/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI026/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI026/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI026/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI026/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI026/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI027/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI027/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI027/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI027/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI027/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI027/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI028/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI028/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI028/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI028/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI028/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI028/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI029/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI029/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI029/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI029/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI029/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI029/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI030/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI030/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI030/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI030/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI030/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI030/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI031/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI031/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI031/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI031/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI031/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI031/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI033/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI033/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI033/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI033/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI033/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI033/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI034/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI034/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI034/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI034/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI034/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI034/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI035/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI035/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI035/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI035/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI035/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI035/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI036/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI036/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI036/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI036/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI036/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI036/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI037/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI037/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI037/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI037/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI037/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI037/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI038/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI038/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI038/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI038/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI038/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI038/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI039/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI039/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI039/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI039/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI039/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI039/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI040/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI040/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI040/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI040/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI040/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI040/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI041/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI041/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI041/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI041/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI041/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI041/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI042/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI042/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI042/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI042/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI042/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI042/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI043/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI043/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI043/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI043/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI043/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI043/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI044/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI044/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI044/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI044/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI044/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI044/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI045/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI045/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI045/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI045/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI045/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI045/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI046/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI046/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI046/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI046/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI046/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI046/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI048/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI048/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI048/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI048/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI048/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI048/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI049/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI049/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI049/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI049/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI049/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI049/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI050/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI050/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI050/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI050/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI050/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI050/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI051/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI051/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI051/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI051/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI051/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI051/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI052/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI052/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI052/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI052/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI052/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI052/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI053/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI053/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI053/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI053/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI053/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI053/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI054/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI054/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI054/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI054/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI054/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI054/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI055/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI055/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI055/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI055/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI055/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI055/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI056/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI056/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI056/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI056/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI056/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI056/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI057/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI057/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI057/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI057/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI057/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI057/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI058/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI058/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI058/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI058/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI058/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI058/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI059/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI059/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI059/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI059/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI059/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI059/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI060/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI060/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI060/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI060/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI060/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI060/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI061/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI061/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI061/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI061/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI061/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI061/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI062/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI062/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI062/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI062/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI062/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI062/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI063/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI063/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI063/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI063/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI063/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI063/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI064/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI064/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI064/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI064/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI064/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI064/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI065/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI065/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI065/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI065/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI065/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI065/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI066/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI066/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI066/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI066/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI066/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI066/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI067/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI067/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI067/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI067/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI067/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI067/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI068/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI068/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI068/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI068/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI068/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI068/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI069/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI069/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI069/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI069/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI069/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI069/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI070/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI070/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI070/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI070/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI070/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI070/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI071/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI071/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI071/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI071/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI071/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI071/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI072/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI072/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI072/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI072/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI072/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI072/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI073/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI073/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI073/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI073/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI073/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI073/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI074/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI074/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI074/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI074/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI074/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI074/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI075/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI075/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI075/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI075/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI075/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI075/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI076/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI076/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI076/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI076/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI076/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI076/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI077/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI077/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI077/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI077/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI077/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI077/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI078/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI078/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI078/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI078/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI078/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI078/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI079/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI079/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI079/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI079/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI079/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI079/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI080/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI080/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI080/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI080/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI080/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI080/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI081/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI081/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI081/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI081/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI081/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI081/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI083/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI083/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI083/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI083/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI083/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI083/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI084/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI084/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI084/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI084/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI084/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI084/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI085/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI085/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI085/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI085/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI085/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI085/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI086/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI086/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI086/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI086/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI086/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI086/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI087/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI087/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI087/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI087/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI087/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI087/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI088/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI088/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI088/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI088/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI088/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI088/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI089/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI089/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI089/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI089/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI089/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI089/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI090/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI090/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI090/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI090/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI090/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI090/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI091/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI091/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI091/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI091/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI091/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI091/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI092/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI092/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI092/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI092/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI092/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI092/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI093/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI093/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI093/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI093/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI093/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI093/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI094/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI094/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI094/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI094/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI094/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI094/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI095/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI095/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI095/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI095/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI095/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI095/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI096/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI096/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI096/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI096/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI096/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI096/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI097/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI097/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI097/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI097/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI097/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI097/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI098/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI098/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI098/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI098/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI098/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI098/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI099/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI099/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI099/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI099/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI099/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI099/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI100/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI100/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI100/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI100/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI100/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI100/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI101/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI101/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI101/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI101/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI101/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI101/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI102/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI102/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI102/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI102/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI102/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI102/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI103/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI103/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI103/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI103/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI103/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI103/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI104/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI104/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI104/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI104/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI104/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI104/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI105/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI105/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI105/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI105/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI105/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI105/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI106/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI106/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI106/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI106/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI106/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI106/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI107/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI107/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI107/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI107/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI107/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI107/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI108/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI108/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI108/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI108/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI108/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI108/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI109/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI109/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI109/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI109/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI109/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI109/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI110/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI110/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI110/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI110/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI110/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI110/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI111/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI111/label/lh.aparc.DKTatlas.annot
# ...
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI617/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI617/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI617/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI617/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI617/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI617/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI618/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI618/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI618/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI618/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI618/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI618/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI619/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI619/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI619/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI619/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI619/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI619/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI621/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI621/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI621/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI621/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI621/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI621/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI622/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI622/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI622/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI622/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI622/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI622/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI623/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI623/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI623/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI623/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI623/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI623/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI625/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI625/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI625/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI625/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI625/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI625/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI626/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI626/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI626/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI626/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI626/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI626/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI627/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI627/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI627/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI627/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI627/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI627/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI629/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI629/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI629/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI629/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI629/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI629/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI630/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI630/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI630/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI630/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI630/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI630/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI631/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI631/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI631/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI631/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI631/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI631/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI632/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI632/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI632/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI632/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI632/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI632/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI633/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI633/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI633/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI633/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI633/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI633/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI634/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI634/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI634/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI634/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI634/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI634/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI635/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI635/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI635/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI635/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI635/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI635/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI636/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI636/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI636/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI636/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI636/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI636/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI637/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI637/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI637/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI637/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI637/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI637/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI638/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI638/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI638/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI638/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI638/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI638/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI639/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI639/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI639/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI639/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI639/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI639/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI640/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI640/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI640/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI640/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI640/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI640/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI641/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI641/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI641/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI641/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI641/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI641/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI642/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI642/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI642/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI642/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI642/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI642/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI643/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI643/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI643/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI643/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI643/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI643/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI644/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI644/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI644/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI644/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI644/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI644/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI646/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI646/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI646/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI646/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI646/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI646/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI648/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI648/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI648/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI648/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI648/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI648/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI651/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI651/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI651/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI651/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI651/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI651/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI652/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI652/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI652/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI652/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI652/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI652/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI653/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI653/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI653/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI653/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI653/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI653/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI661/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI661/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI661/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI661/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI661/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI661/surf/rh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI662/surf/lh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI662/label/lh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI662/surf/lh.pial
# Processing...
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI662/surf/rh.thickness
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI662/label/rh.aparc.DKTatlas.annot
# /var/datasets/IXI/freesurfer8/preproc_subjects/sub-IXI662/surf/rh.pial
# Processing...

# %%
thickness_df
# Out:
#       subject_id hemi                   region  mean_thickness_weighted  \
# 0         IXI002   lh                  unknown                 0.000369
# 1         IXI002   lh  caudalanteriorcingulate                 2.767575
# 2         IXI002   lh      caudalmiddlefrontal                 2.828643
# 3         IXI002   lh                   cuneus                 2.019888
# 4         IXI002   lh               entorhinal                 2.712761
# ...          ...  ...                      ...                      ...
# 37063     IXI662   rh         superiorparietal                 2.120859
# 37064     IXI662   rh         superiortemporal                 2.965944
# 37065     IXI662   rh            supramarginal                 2.508402
# 37066     IXI662   rh       transversetemporal                 2.354042
# 37067     IXI662   rh                   insula                 3.162511
#
#        mean_thickness_simple  n_vertices   total_area
# 0                   0.000338        8853  5502.432653
# 1                   2.609781        1437  1083.926104
# 2                   2.690581        3830  2769.405243
# 3                   2.020947        2739  2037.500121
# 4                   2.636525         708   687.427367
# ...                      ...         ...          ...
# 37063               2.023058        6653  5314.046982
# 37064               2.796967        8804  7119.010455
# 37065               2.370133        5606  4399.206890
# 37066               2.350365         628   446.668808
# 37067               3.093791        3507  2240.559767
#
# [37068 rows x 7 columns]

# %%
thickness_df.to_csv("../../data/IXI/thickness.csv", index=False)
